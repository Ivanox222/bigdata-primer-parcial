# %% [markdown]
# # Ejercicio 1: Clasificación de edad
# - Solicite o defina una edad y determine la categoría correspondiente.
# - logica: se uso if, elif y else. para ejecutar los caso

# %%
def clasificar_edad(edad):
    if edad < 13:
        return "Niño"
    elif edad < 18:
        return "Adolescente"
    elif edad < 59:
        return "Adulto"
    else:
        return "Adulto mayor"

edad = 21
categoria = clasificar_edad(edad)
print(f"Una persona de {edad} años es un {categoria}.")
# Out:
# Una persona de 21 años es un Adulto.

# %% [markdown]
# # Ejercicio 2: Conversor de temperatura
# - Convierta una temperatura de grados Celsius a Fahrenheit.

# %%
celsius = 30
fahrenheit = (celsius * 9/5) + 32

print(fahrenheit)
# Out:
# 86.0
